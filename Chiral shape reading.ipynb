# %%
def read_dataset(file_location):
    '''
    Read Dataset from CSV file for Active matter project

    input:
        file_location: Give the "absolute" location of the CSV file to read from

    output:
        This Function does not return anything BUT
        all the variables that are printed can be used directly
    '''
    file = pd.read_csv(file_location)
    print("The variables in the database are (Can be used directly by calling)-")
    print('number_of_data')
    global number_of_data
    number_of_data = len(file)
    for col in file.columns:
        print(col)
        globals()[col] = file[col]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
read_dataset('D:/02_Works/01_Projects/Microswimmer/Microswimmer_data/Results/20240112_194451/20210528-ellipse-1.csv')
# Out:
# The variables in the database are (Can be used directly by calling)-
# number_of_data
# time
# p0_x
# p0_y
# p0_theta
# p1_x
# p1_y
# p1_theta
# p2_x
# p2_y
# p2_theta
# p3_x
# p3_y
# p3_theta

# %%
number_of_data
# Out:
# 179

# %%
# Define specific color for particles in order
# Optimally distinct colors
colors = ["#f3bc83",
"#703f81",
"#006a00",
"#e6005a",
"#9ad587",
"#9f5200",
"#ffa741"]

# %%
# trajectory of particles
plt.scatter(p0_x, p0_y, c=colors[0])
plt.scatter(p1_x, p1_y, c=colors[1])
plt.scatter(p2_x, p2_y, c=colors[2])
plt.scatter(p3_x, p3_y, c=colors[3])

# %%
plt.scatter(time, p0_theta, c=colors[0])
plt.scatter(time, p1_theta, c=colors[1])
plt.scatter(time, p2_theta, c=colors[2])
plt.scatter(time, p3_theta, c=colors[3])
